# %%
#Task condition 1.3.1
#Задайте 4 точки в трехмерном пространстве, рассчитайте между ними расстояния по описанным в примере выше метрикам. Отобразите точки в трехмерном пространстве.

#solution
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from termcolor import colored, cprint
print(colored('Введите координаты четырех точек в трехмерном пространстве.', 'red', attrs=['underline']))
print(colored('x1 = ', 'red'))
x1 = int(input())
print(colored('y1 = ', 'red'))
y1 = int(input())
print(colored('z1 = ', 'red'))
z1 = int(input())
print(colored('x2 = ', 'red'))
x2 = int(input())
print(colored('y2 = ', 'red'))
y2 = int(input())
print(colored('z2 = ', 'red'))
z2 = int(input())
print(colored('x3 = ', 'red'))
x3 = int(input())
print(colored('y3 = ', 'red'))
y3 = int(input())
print(colored('z3 = ', 'red'))
z3 = int(input())
print(colored('x4 = ', 'red'))
x4 = int(input())
print(colored('y4 = ', 'red'))
y4 = int(input())
print(colored('z4 = ', 'red'))
z4 = int(input())

p1 = np.array([x1, y1, z1])
p2 = np.array([x2, y2, z2])
p3 = np.array([x3, y3, z3])
p4 = np.array([x4, y4, z4])

print(colored('Расстояние между p1 и p2:', 'red', attrs=['underline']))
print(np.linalg.norm(p2 - p1))
print(np.linalg.norm(p2 - p1) ** 2)
print(np.linalg.norm(p2 - p1, ord=np.inf))
print(np.linalg.norm(p2 - p1, ord=1))

print(colored('Расстояние между p4 и p3:', 'red', attrs=['underline']))
print(np.linalg.norm(p4 - p3))
print(np.linalg.norm(p4 - p3) ** 2)
print(np.linalg.norm(p4 - p3, ord=np.inf))
print(np.linalg.norm(p4 - p3, ord=1))

print(colored('Расстояние между p3 и p1:', 'red', attrs=['underline']))
print(np.linalg.norm(p3 - p1))
print(np.linalg.norm(p3 - p1) ** 2)
print(np.linalg.norm(p3 - p1, ord=np.inf))
print(np.linalg.norm(p3 - p1, ord=1))

print(colored('Расстояние между p4 и p2:', 'red', attrs=['underline']))
print(np.linalg.norm(p4 - p2))
print(np.linalg.norm(p4 - p2) ** 2)
print(np.linalg.norm(p4 - p2, ord=np.inf))
print(np.linalg.norm(p4 - p2, ord=1))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(p1[0], p1[1], p1[2])
ax.scatter(p2[0], p2[1], p2[2])
ax.scatter(p3[0], p3[1], p3[2])
ax.scatter(p4[0], p4[1], p4[2])
plt.show()
# Out:
# Введите координаты четырех точек в трехмерном пространстве.
# x1 =
# 0
# y1 =
# 0
# z1 =
# 0
# x2 =
# 1
# y2 =
# 1
# z2 =
# 1
# x3 =
# 2
# y3 =
# 2
# z3 =
# 2
# x4 =
# 3
# y4 =
# 3
# z4 =
# 3
# Расстояние между p1 и p2:
# 1.7320508075688772
# 2.9999999999999996
# 1.0
# 3.0
# Расстояние между p4 и p3:
# 1.7320508075688772
# 2.9999999999999996
# 1.0
# 3.0
# Расстояние между p3 и p1:
# 3.4641016151377544
# 11.999999999999998
# 2.0
# 6.0
# Расстояние между p4 и p2:
# 3.4641016151377544
# 11.999999999999998
# 2.0
# 6.0

# %%
#Task condition 2.3.1
#Для предыдущего примера поэкспериментируйте с параметрами классификатора:
#1. Установите другое количество ближайших соседей (k = 1, 5, 10).
#2. Установите размер тестовой выборки 15% от всего датасета.
#3. Постройте графики и оцените качество моделей, проанализируйте результаты.

#solution
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

iris = sns.load_dataset('iris')
iris
x_train, x_test, y_train, y_test = train_test_split(
    iris.iloc[:, :-1],
    iris.iloc[:, -1],
    test_size=0.15
)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)

print(x_train.head())
print(y_train.head())

def func(k):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train, y_train)
 
    y_pred = model.predict(x_test)
    print(y_pred)

    plt.figure(figsize=(10, 7))
    sns.scatterplot(x='petal_width', y='petal_length', data=iris, hue='species', s=70)
    plt.xlabel('Длина лепестка, см')
    plt.ylabel('Ширина лепестка, см')
    plt.legend(loc=2)
    plt.grid()

    for i in range(len(y_test)):
        if np.array(y_test)[i] != y_pred[i]:
            plt.scatter(x_test.iloc[i, 3], x_test.iloc[i, 2], color='red', s=150)

    print(f'accuracy: {accuracy_score(y_test, y_pred):.3}')

func(1)
func(5)
func(10)
# Out:
# (127, 4) (23, 4) (127,) (23,)
#      sepal_length  sepal_width  petal_length  petal_width
# 130           7.4          2.8           6.1          1.9
# 53            5.5          2.3           4.0          1.3
# 127           6.1          3.0           4.9          1.8
# 39            5.1          3.4           1.5          0.2
# 123           6.3          2.7           4.9          1.8
# 130     virginica
# 53     versicolor
# 127     virginica
# 39         setosa
# 123     virginica
# Name: species, dtype: object
# ['virginica' 'setosa' 'virginica' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'setosa' 'setosa' 'virginica' 'virginica' 'virginica'
#  'versicolor' 'setosa' 'setosa' 'setosa' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica']
# accuracy: 0.957
# ['virginica' 'setosa' 'virginica' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'setosa' 'setosa' 'virginica' 'virginica' 'virginica'
#  'virginica' 'setosa' 'setosa' 'setosa' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica']
# accuracy: 0.913
# ['virginica' 'setosa' 'virginica' 'versicolor' 'virginica' 'setosa'
#  'versicolor' 'setosa' 'setosa' 'versicolor' 'virginica' 'virginica'
#  'versicolor' 'setosa' 'setosa' 'setosa' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'versicolor' 'versicolor' 'virginica']
# accuracy: 1.0

# %%
#Task condition 2.3.1
#Определите набор признаков человека, по аналогии из РТ 1, – например, цвет глаз и конвертируйте его в матрицу признаков.

#solution
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
data_dict = [{'карий': 2, 'серый': 4},
             {'карий': 5, 'голубой': 4},
             {'карий': 10, 'зеленый': 1}]
dictvectorizer = DictVectorizer(sparse=False)
features = dictvectorizer.fit_transform(data_dict)
features
# Out:
# array([[ 0.,  0.,  2.,  4.],
#        [ 4.,  0.,  5.,  0.],
#        [ 0.,  1., 10.,  0.]])
